# %%
# !pip install sqlalchemy==1.3.23
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 38.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.23-cp311-cp311-linux_x86_64.whl size=1251720 sha256=d65088a98125ac0e0c929b1ff92838b0d3a4c438b44d9f4def5daaf9ab26627e
#   Stored in directory: /root/.cache/pip/wheels/9a/b4/0a/397d6c6756b530b1ef4ce62a420c955ef1af20a1ca5cc85612
# Successfully built sqlalchemy
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.37
#     Uninstalling SQLAlchemy-2.0.37:
#       Successfully uninstalled SQLAlchemy-2.0.37
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.16 requires SQLAlchemy<3,>=1.4, but you have sqlalchemy 1.3.23 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.23 which is incompatible.
# ...

# %%
# !pip install ipython-sql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.23
#     Uninstalling SQLAlchemy-1.3.23:
#       Successfully uninstalled SQLAlchemy-1.3.23
# ...

# %% [markdown]
# Load the SQL extension

# %%
# %load_ext sql

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %sql sqlite:////content/drive/MyDrive/db/chinook.db

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type= 'table' AND name NOT LIKE 'sqlite_%';
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-fb6c631ef973> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "SELECT name FROM sqlite_master WHERE type= 'table' AND name NOT LIKE 'sqlite_%';\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# ...

# %%
# %%sql
# -- create new table and embed it into chinook database
# CREATE TABLE Shoes (
#   Id int PRIMARY KEY,
#   Brand char(10) NOT NULL,
#   Type char(250) NOT NUll,
#   Color char(250) NOT NULL,
#   Price decimal(8,2) NOT NULL,
#   Desc varchar(750) NULL
#
# );
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# []

# %%
# %%sql
# -- check created table
# SELECT name FROM sqlite_master WHERE type= 'table' AND name NOT LIKE 'sqlite';
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-90f1d1c0fd36> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "-- check created table\nSELECT name FROM sqlite_master WHERE type= 'table' AND name NOT LIKE 'sqlite';\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
# ...

# %%
# %%sql
# INSERT INTO Shoes
#  (Id,
#   Brand,
#   Type,
#   Color,
#   Price,
#   Desc
#  )
# VALUES
#   ('1',
#   'Nike',
#   'Air Max',
#   'Black',
#   '200.00',
#   NULL
#   );
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM Shoes;
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# [(1, 'Nike', 'Air Max', 'Black', 200, None)]

# %%
# %%sql
# -- deleting tables
# DROP TABLE Shoes;
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# []

# %%
# %%sql
# -- check if the table was deleted
# SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# [('albums',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',)]

# %% [markdown]
# ClASS EXERCISE 6

# %%
# %%sql
# SELECT *
# FROM customers
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# [(1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (2, 'Leonie', 'Köhler', None, 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', '+49 0711 2842222', None, 'leonekohler@surfeu.de', 5),
#  (3, 'François', 'Tremblay', None, '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', '+1 (514) 721-4711', None, 'ftremblay@gmail.com', 3),
#  (4, 'Bjørn', 'Hansen', None, 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', '+47 22 44 22 22', None, 'bjorn.hansen@yahoo.no', 4),
#  (5, 'František', 'Wichterlová', 'JetBrains s.r.o.', 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', '+420 2 4172 5555', '+420 2 4172 5555', 'frantisekw@jetbrains.com', 4),
# ...

# %%
# %%sql
# CREATE TABLE customers_usa AS
# SELECT *
# FROM customers
# where country= 'USA'
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# []

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%'
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# [('albums',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('customers_usa',)]

# %%
# %%sql
# SELECT *
# FROM customers_usa
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# [(16, 'Frank', 'Harris', 'Google Inc.', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', '+1 (650) 253-0000', '+1 (650) 253-0000', 'fharris@google.com', 4),
#  (17, 'Jack', 'Smith', 'Microsoft Corporation', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', '+1 (425) 882-8080', '+1 (425) 882-8081', 'jacksmith@microsoft.com', 5),
#  (18, 'Michelle', 'Brooks', None, '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', '+1 (212) 221-3546', '+1 (212) 221-4679', 'michelleb@aol.com', 3),
#  (19, 'Tim', 'Goyer', 'Apple Inc.', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', '+1 (408) 996-1010', '+1 (408) 996-1011', 'tgoyer@apple.com', 3),
#  (20, 'Dan', 'Miller', None, '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', '+1 (650) 644-3358', None, 'dmiller@comcast.com', 4),
# ...

# %%
# %%sql
# DELETE FROM customers_usa
# WHERE SupportRepId = '4';
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# 6 rows affected.
# []

# %%
# %%sql
# ALTER TABLE customers_usa
# ADD COLUMN coupon_code varchar(750);
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# []

# %%
# %%sql
# UPDATE customers_usa
# SET coupon_code= 'Your 65% Coupon';
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# 7 rows affected.
# []

# %%
# %%sql
# Select *
# from customers_usa
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# [(17, 'Jack', 'Smith', 'Microsoft Corporation', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', '+1 (425) 882-8080', '+1 (425) 882-8081', 'jacksmith@microsoft.com', 5, 'Your 65% Coupon'),
#  (18, 'Michelle', 'Brooks', None, '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', '+1 (212) 221-3546', '+1 (212) 221-4679', 'michelleb@aol.com', 3, 'Your 65% Coupon'),
#  (19, 'Tim', 'Goyer', 'Apple Inc.', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', '+1 (408) 996-1010', '+1 (408) 996-1011', 'tgoyer@apple.com', 3, 'Your 65% Coupon'),
#  (21, 'Kathy', 'Chase', None, '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', '+1 (775) 223-7665', None, 'kachase@hotmail.com', 5, 'Your 65% Coupon'),
#  (24, 'Frank', 'Ralston', None, '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', '+1 (312) 332-3232', None, 'fralston@gmail.com', 3, 'Your 65% Coupon'),
# ...

# %%
# %%sql
# DROP TABLE customers_usa
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# []

# %%
# %%sql
# SELECT name FROM sqlite_master where type= 'table' AND name NOT LIKE 'sqlite_%'
# Out:
#  * sqlite:////content/drive/MyDrive/db/chinook.db
# Done.
# [('albums',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',)]
